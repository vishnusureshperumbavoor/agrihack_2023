# %%
import numpy as np
import seaborn as sb
import pandas as pd

# %%
df = pd.read_excel('crop_price_prediction.xlsx')

# %%
df.head()
# Out:
#    Sl no. District Name Market Name Commodity        Variety   Grade  \
# 0       1     Ernakulam       Aluva    Banana  Palayamthodan   Large
# 1       2     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 2       3     Ernakulam       Aluva    Banana         Poovan  Medium
# 3       4     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 4       5     Ernakulam       Aluva    Banana         Poovan  Medium
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     1000                     1200
# 1                     1000                     1500
# 2                     2700                     2900
# 3                     1300                     1500
# 4                     2800                     3000
#
#    Modal Price (Rs./Quintal) Price Date                      Date    new_Date
# 0                       1100 2021-12-19 2021-12-19 00:00:00+00:00  2021-12-19
# 1                       1300 2021-12-05 2021-12-05 00:00:00+00:00  2021-12-05
# 2                       2800 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 3                       1400 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 4                       2900 2021-11-30 2021-11-30 00:00:00+00:00  2021-11-30

# %% [markdown]
# # Changing datatype of date from datetime to object

# %%
from datetime import datetime
def convert_datetime(dt):
    return datetime.strftime(dt, '%Y-%m-%d %H:%M-%S')

df['Date']= df ['Price Date'].apply(convert_datetime)

# %% [markdown]
# # Removing timestamp from the column

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['new_Date'] = df['Date'].dt.date

# %%
df.head()
# Out:
#    Sl no. District Name Market Name Commodity        Variety   Grade  \
# 0       1     Ernakulam       Aluva    Banana  Palayamthodan   Large
# 1       2     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 2       3     Ernakulam       Aluva    Banana         Poovan  Medium
# 3       4     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 4       5     Ernakulam       Aluva    Banana         Poovan  Medium
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     1000                     1200
# 1                     1000                     1500
# 2                     2700                     2900
# 3                     1300                     1500
# 4                     2800                     3000
#
#    Modal Price (Rs./Quintal) Price Date                      Date    new_Date
# 0                       1100 2021-12-19 2021-12-19 00:00:00+00:00  2021-12-19
# 1                       1300 2021-12-05 2021-12-05 00:00:00+00:00  2021-12-05
# 2                       2800 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 3                       1400 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 4                       2900 2021-11-30 2021-11-30 00:00:00+00:00  2021-11-30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15535 entries, 0 to 15534
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl no.                     15535 non-null  int64
#  1   District Name              15535 non-null  object
#  2   Market Name                15535 non-null  object
#  3   Commodity                  15535 non-null  object
#  4   Variety                    15535 non-null  object
#  5   Grade                      15535 non-null  object
#  6   Min Price (Rs./Quintal)    15535 non-null  int64
#  7   Max Price (Rs./Quintal)    15535 non-null  int64
#  8   Modal Price (Rs./Quintal)  15535 non-null  int64
#  9   Price Date                 15535 non-null  datetime64[ns]
#  10  Date                       15535 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# # Droping Price Date and Date column

# %%
df.drop(['Price Date', 'Date'], axis=1)
df.head()
# Out:
#    Sl no. District Name Market Name Commodity        Variety   Grade  \
# 0       1     Ernakulam       Aluva    Banana  Palayamthodan   Large
# 1       2     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 2       3     Ernakulam       Aluva    Banana         Poovan  Medium
# 3       4     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 4       5     Ernakulam       Aluva    Banana         Poovan  Medium
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     1000                     1200
# 1                     1000                     1500
# 2                     2700                     2900
# 3                     1300                     1500
# 4                     2800                     3000
#
#    Modal Price (Rs./Quintal) Price Date                      Date    new_Date
# 0                       1100 2021-12-19 2021-12-19 00:00:00+00:00  2021-12-19
# 1                       1300 2021-12-05 2021-12-05 00:00:00+00:00  2021-12-05
# 2                       2800 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 3                       1400 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 4                       2900 2021-11-30 2021-11-30 00:00:00+00:00  2021-11-30

# %%
df.head()
# Out:
#    Sl no. District Name Market Name Commodity        Variety   Grade  \
# 0       1     Ernakulam       Aluva    Banana  Palayamthodan   Large
# 1       2     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 2       3     Ernakulam       Aluva    Banana         Poovan  Medium
# 3       4     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 4       5     Ernakulam       Aluva    Banana         Poovan  Medium
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     1000                     1200
# 1                     1000                     1500
# 2                     2700                     2900
# 3                     1300                     1500
# 4                     2800                     3000
#
#    Modal Price (Rs./Quintal) Price Date                      Date    new_Date
# 0                       1100 2021-12-19 2021-12-19 00:00:00+00:00  2021-12-19
# 1                       1300 2021-12-05 2021-12-05 00:00:00+00:00  2021-12-05
# 2                       2800 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 3                       1400 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 4                       2900 2021-11-30 2021-11-30 00:00:00+00:00  2021-11-30

# %%
df.drop(['Price Date'], axis=1)
df.head()
# Out:
#    Sl no. District Name Market Name Commodity        Variety   Grade  \
# 0       1     Ernakulam       Aluva    Banana  Palayamthodan   Large
# 1       2     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 2       3     Ernakulam       Aluva    Banana         Poovan  Medium
# 3       4     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 4       5     Ernakulam       Aluva    Banana         Poovan  Medium
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     1000                     1200
# 1                     1000                     1500
# 2                     2700                     2900
# 3                     1300                     1500
# 4                     2800                     3000
#
#    Modal Price (Rs./Quintal) Price Date                      Date    new_Date
# 0                       1100 2021-12-19 2021-12-19 00:00:00+00:00  2021-12-19
# 1                       1300 2021-12-05 2021-12-05 00:00:00+00:00  2021-12-05
# 2                       2800 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 3                       1400 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 4                       2900 2021-11-30 2021-11-30 00:00:00+00:00  2021-11-30

# %%
df.drop(['Date'], axis=1)
df.head()
# Out:
#    Sl no. District Name Market Name Commodity        Variety   Grade  \
# 0       1     Ernakulam       Aluva    Banana  Palayamthodan   Large
# 1       2     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 2       3     Ernakulam       Aluva    Banana         Poovan  Medium
# 3       4     Ernakulam       Aluva    Banana  Palayamthodan  Medium
# 4       5     Ernakulam       Aluva    Banana         Poovan  Medium
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     1000                     1200
# 1                     1000                     1500
# 2                     2700                     2900
# 3                     1300                     1500
# 4                     2800                     3000
#
#    Modal Price (Rs./Quintal) Price Date                      Date    new_Date
# 0                       1100 2021-12-19 2021-12-19 00:00:00+00:00  2021-12-19
# 1                       1300 2021-12-05 2021-12-05 00:00:00+00:00  2021-12-05
# 2                       2800 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 3                       1400 2021-12-01 2021-12-01 00:00:00+00:00  2021-12-01
# 4                       2900 2021-11-30 2021-11-30 00:00:00+00:00  2021-11-30

# %%
df.isnull().sum()
# Out:
# Sl no.                       0
# District Name                0
# Market Name                  0
# Commodity                    0
# Variety                      0
# Grade                        0
# Min Price (Rs./Quintal)      0
# Max Price (Rs./Quintal)      0
# Modal Price (Rs./Quintal)    0
# Price Date                   0
# Date                         0
# new_Date                     0
# dtype: int64

# %%
df["Price Date"][28]
# Out:
# Timestamp('2021-11-15 00:00:00')

# %%
df.shape
# Out:
# (15535, 11)

# %%
df["Date"].head
# Out:
# <bound method NDFrame.head of 0        2021-12-19 00:00-00
# 1        2021-12-05 00:00-00
# 2        2021-12-01 00:00-00
# 3        2021-12-01 00:00-00
# 4        2021-11-30 00:00-00
#                 ...
# 15530    2013-02-25 00:00-00
# 15531    2013-02-18 00:00-00
# 15532    2013-02-18 00:00-00
# 15533    2013-02-14 00:00-00
# 15534    2013-02-14 00:00-00
# Name: Date, Length: 15535, dtype: object>

# %%
str = df["Date"][1]
str2 = str.split('-')
print(str)
print(str2)
print(str2[1])
# Out:
# 2021-12-05 00:00-00
# ['2021', '12', '05 00:00', '00']
# 12

# %%
dict = {1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"June",7:"July",8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"}
print(dict)
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'June', 7: 'July', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

# %%
dict[1]
# Out:
# 'Jan'

# %%
month_column = []

# %%
for rr in df["Price Date"]:
    str = rr
    str2 = str.split('-')
    month_column.append(dict[int(str2[1])])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 for rr in df["Price Date"]:
#       2     str = rr
# ----> 3     str2 = str.split('-')
#       4     month_column.append(dict[int(str2[1])])
#
# AttributeError: 'Timestamp' object has no attribute 'split'
